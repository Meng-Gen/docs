# %%
import tensorflow as tf
from scipy.io import loadmat

matfile = loadmat('ex6data1.mat')

def input_fn():
    return {
        'example_id': tf.constant([str(_) for _ in range(len(matfile['X']))]),
        'feature1': tf.constant(matfile['X'][:,[0]]),
        'feature2': tf.constant(matfile['X'][:,[1]]),
    }, tf.constant(matfile['y'])

feature1 = tf.contrib.layers.real_valued_column('feature1')
feature2 = tf.contrib.layers.real_valued_column('feature2')

svm_classifier = tf.contrib.learn.SVM(feature_columns=[feature1, feature2], 
                                      example_id_column='example_id',
                                      l1_regularization=0.0,
                                      l2_regularization=0.0)

svm_classifier.fit(input_fn=input_fn, steps=1000)
metrics = svm_classifier.evaluate(input_fn=input_fn, steps=1)

print metrics
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': None, '_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': None, '_environment': 'local', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11b6bd850>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_num_worker_replicas': 0, '_task_id': 0, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_master': ''}
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpY5yeQi
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# INFO:tensorflow:Created variable linear/bias_weight:0, with device=
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1194: hinge_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.hinge_loss instead. Note that the order of the predictions and labels arguments were changed.
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpY5yeQi/model.ckpt.
# INFO:tensorflow:loss = 1.0, step = 1
# INFO:tensorflow:global_step/sec: 964.199
# INFO:tensorflow:loss = 0.505029, step = 101 (0.105 sec)
# INFO:tensorflow:global_step/sec: 970.338
# INFO:tensorflow:loss = 0.225835, step = 201 (0.103 sec)
# INFO:tensorflow:global_step/sec: 946.727
# INFO:tensorflow:loss = 0.303017, step = 301 (0.106 sec)
# INFO:tensorflow:global_step/sec: 755.95
# INFO:tensorflow:loss = 0.29948, step = 401 (0.132 sec)
# INFO:tensorflow:global_step/sec: 920.021
# INFO:tensorflow:loss = 0.298631, step = 501 (0.109 sec)
# INFO:tensorflow:global_step/sec: 914.671
# INFO:tensorflow:loss = 0.29418, step = 601 (0.109 sec)
# INFO:tensorflow:global_step/sec: 866.447
# INFO:tensorflow:loss = 0.294304, step = 701 (0.124 sec)
# INFO:tensorflow:global_step/sec: 581.135
# INFO:tensorflow:loss = 0.294414, step = 801 (0.164 sec)
# INFO:tensorflow:global_step/sec: 745.991
# INFO:tensorflow:loss = 0.29445, step = 901 (0.135 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpY5yeQi/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.294463.
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# INFO:tensorflow:Created variable linear/bias_weight:0, with device=
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1194: hinge_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.hinge_loss instead. Note that the order of the predictions and labels arguments were changed.
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-05-17-14:19:35
# INFO:tensorflow:Restoring parameters from /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpY5yeQi/model.ckpt-1000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-05-17-14:19:35
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.980392, global_step = 1000, loss = 0.294463
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# {'loss': 0.29446274, 'global_step': 1000, 'accuracy': 0.98039216}

# %%
import tensorflow as tf
from scipy.io import loadmat

matfile = loadmat('ex6data1.mat')

def input_fn():
    return {
        'example_id': tf.constant([str(_) for _ in range(len(matfile['X']))]),
        'feature': tf.constant(matfile['X']),
    }, tf.constant(matfile['y'])

feature = tf.contrib.layers.real_valued_column('feature')

svm_classifier = tf.contrib.learn.SVM(feature_columns=[feature], 
                                      example_id_column='example_id',
                                      l1_regularization=0.0,
                                      l2_regularization=0.0)

svm_classifier.fit(input_fn=input_fn, steps=1000)
metrics = svm_classifier.evaluate(input_fn=input_fn, steps=1)

print metrics
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': None, '_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': None, '_environment': 'local', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11b53ad90>, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_num_worker_replicas': 0, '_task_id': 0, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_master': ''}
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpKyFAH0
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# INFO:tensorflow:Created variable linear/bias_weight:0, with device=
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1194: hinge_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.hinge_loss instead. Note that the order of the predictions and labels arguments were changed.
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpKyFAH0/model.ckpt.
# INFO:tensorflow:loss = 1.0, step = 1
# INFO:tensorflow:global_step/sec: 891.631
# INFO:tensorflow:loss = 0.505029, step = 101 (0.113 sec)
# INFO:tensorflow:global_step/sec: 908.784
# INFO:tensorflow:loss = 0.225835, step = 201 (0.111 sec)
# INFO:tensorflow:global_step/sec: 1065.4
# INFO:tensorflow:loss = 0.303017, step = 301 (0.093 sec)
# INFO:tensorflow:global_step/sec: 873.049
# INFO:tensorflow:loss = 0.29948, step = 401 (0.114 sec)
# INFO:tensorflow:global_step/sec: 1004.98
# INFO:tensorflow:loss = 0.298631, step = 501 (0.100 sec)
# INFO:tensorflow:global_step/sec: 1034.17
# INFO:tensorflow:loss = 0.29418, step = 601 (0.097 sec)
# INFO:tensorflow:global_step/sec: 920.92
# INFO:tensorflow:loss = 0.294304, step = 701 (0.109 sec)
# INFO:tensorflow:global_step/sec: 1064.41
# INFO:tensorflow:loss = 0.294414, step = 801 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1044.84
# INFO:tensorflow:loss = 0.29445, step = 901 (0.096 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpKyFAH0/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.294463.
# WARNING:tensorflow:tf.variable_op_scope(values, name, default_name) is deprecated, use tf.variable_scope(name, default_name, values)
# INFO:tensorflow:Created variable linear/bias_weight:0, with device=
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1194: hinge_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.hinge_loss instead. Note that the order of the predictions and labels arguments were changed.
# WARNING:tensorflow:From /Users/menggen/anaconda/envs/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-05-17-14:20:19
# INFO:tensorflow:Restoring parameters from /var/folders/_6/l1_h6_0n70dc5ffhsc79r89w0000gn/T/tmpKyFAH0/model.ckpt-1000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-05-17-14:20:19
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.980392, global_step = 1000, loss = 0.294463
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# {'loss': 0.29446277, 'global_step': 1000, 'accuracy': 0.98039216}
